# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # A notebook to analyze backtesting results
#
# This simple notebook is to be used to
# - visualize the spread between the theoretical price of an option and the price of the corresponding hedging portfolio,
# - compute the tracking error for the hedging portfolio.
# It takes as an input the json file containing the output data produced by the hedger.

# %% [markdown]
# ## Set the path to the file to investigate

# %%
RESULTS = 'portfolio1.json'
EXPECTED = 'params/lelong-portfolio1.json'

# %%
res_df = pd.read_json(RESULTS, convert_dates=['date'])
exp_df = pd.read_json(EXPECTED, convert_dates=['OutputDate'])

res_df.sort_values(by='date', inplace=True)
res_df.set_index('date', inplace=True)

exp_df.sort_values(by='OutputDate', inplace=True)
exp_df.set_index('OutputDate', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 res_df = pd.read_json(RESULTS, convert_dates=['date'])
# ----> 2 exp_df = pd.read_json(EXPECTED, convert_dates=['OutputDate'])
#       4 res_df.sort_values(by='date', inplace=True)
#       5 res_df.set_index('date', inplace=True)
#
# File c:\Users\lamur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
#     783     typ=typ,
#     784     dtype=dtype,
# ...

# %% [markdown]
# ## Plot the portfolio value against the theoretical price

# %%
ax = plt.gca()
res_df.plot(y = 'value', color='orange', ax = ax)
res_df.plot(y = 'price', color = 'red', ax = ax)

exp_df.plot(y = 'PortfolioValue', color='blue', ax = ax)
exp_df.plot(y = 'Price', color = 'green', ax = ax)

xcoords = ["2022-05-03T00:00:00",
      "2022-06-03T00:00:00",
      "2022-09-06T00:00:00",
      "2023-01-03T00:00:00"]
for xc in xcoords:
    plt.axvline(x=xc, color='black')

plt.show()

# %% [markdown]
# ## Compute the tracking error

# %%
tracking_error = (res_df['value'][-1] - res_df.price[-1])/res_df.price[0]
print(f'Tracking error: {tracking_error:.2%}')
# Out:
# Tracking error: 35.84%
